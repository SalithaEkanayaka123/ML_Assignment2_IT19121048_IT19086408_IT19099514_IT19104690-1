# %% [markdown]
# <a href="https://colab.research.google.com/github/AnawaratneMANA/ML_Assignment2_IT19121048_IT19086408_IT19099514_IT19104690/blob/main/Maching_learning_Assingment_II.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Machine learning notebook for M

# %% [markdown]
# ## hi

# %% [markdown]
# #### another commit
